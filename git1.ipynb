# %%
# !pip install opencv-python-headless matplotlib
# Out:
# Requirement already satisfied: opencv-python-headless in ./Desktop/Udemy/venv/lib/python3.11/site-packages (4.10.0.84)
# Requirement already satisfied: matplotlib in ./Desktop/Udemy/venv/lib/python3.11/site-packages (3.9.0)
# Requirement already satisfied: numpy>=1.21.2 in ./Desktop/Udemy/venv/lib/python3.11/site-packages (from opencv-python-headless) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./Desktop/Udemy/venv/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./Desktop/Udemy/venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./Desktop/Udemy/venv/lib/python3.11/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./Desktop/Udemy/venv/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./Desktop/Udemy/venv/lib/python3.11/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in ./Desktop/Udemy/venv/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./Desktop/Udemy/venv/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./Desktop/Udemy/venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./Desktop/Udemy/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from tkinter import filedialog
from tkinter import Tk

# %%
def upload_image():
    root = Tk()
    root.withdraw()  # Hide the root window
    file_path = filedialog.askopenfilename()  # Open file dialog
    return file_path

# %%
file_path = upload_image()
image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)

# %%
kernel_size = (3, 3)  # You can change this to other sizes, like (5, 5) or (7, 7)

# Apply the box filter using cv2.blur (which is essentially a box filter)
box_filtered_image = cv2.blur(image, kernel_size)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Box Filtered Image')
plt.imshow(box_filtered_image, cmap='gray')
plt.axis('off')

plt.show()
